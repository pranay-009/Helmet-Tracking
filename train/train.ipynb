# %% [markdown]
# ## Download all files and packages

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/helmet_detection/data/tensorflow/models/research
# Out:
# /content/drive/.shortcut-targets-by-id/1pKyLFjpE3px_b4yXeAi4oKdIQqIqvHIp/helmet_detection/data/tensorflow/models/research

# %%
# !cp -r /content/drive/MyDrive/helmet_detection .
# %cd /content/drive/MyDrive/helmet_detection/data/tensorflow/models/research
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content/drive/.shortcut-targets-by-id/1pKyLFjpE3px_b4yXeAi4oKdIQqIqvHIp/helmet_detection/data/tensorflow/models/research

# %%
# !apt install --allow-change-held-packages libcudnn8=8.1.0.77-1+cuda11.2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following packages will be REMOVED:
#   libcudnn8-dev
# The following held packages will be changed:
#   libcudnn8
# The following packages will be upgraded:
#   libcudnn8
# 1 upgraded, 0 newly installed, 1 to remove and 40 not upgraded.
# Need to get 430 MB of archives.
# After this operation, 3,139 MB disk space will be freed.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcudnn8 8.1.0.77-1+cuda11.2 [430 MB]
# Fetched 430 MB in 7s (63.0 MB/s)
# (Reading database ... 155629 files and directories currently installed.)
# Removing libcudnn8-dev (8.0.5.39-1+cuda11.1) ...
# (Reading database ... 155607 files and directories currently installed.)
# ...

# %%
# !cp object_detection/packages/tf2/setup.py .
# !python -m pip install --use-feature=2020-resolver .
# !pip install opencv-python-headless==4.1.2.30
# Out:
# WARNING: --use-feature=2020-resolver no longer has any effect, since it is now the default dependency resolver in pip. This will become an error in pip 21.0.
# Processing /content/drive/.shortcut-targets-by-id/1pKyLFjpE3px_b4yXeAi4oKdIQqIqvHIp/helmet_detection/data/tensorflow/models/research
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#      |████████████████████████████████| 10.2 MB 8.3 MB/s
# ...
#      |████████████████████████████████| 352 kB 75.4 MB/s
# ...
#      |████████████████████████████████| 489.6 MB 24 kB/s
# ...
#      |████████████████████████████████| 1.8 MB 52.3 MB/s
# ...
#      |████████████████████████████████| 23.1 MB 1.2 MB/s
# ...

# %%
# !python /content/drive/MyDrive/helmet_detection/data/tensorflow/models/research/object_detection/builders/model_builder_tf2_test.py
# Out:
# Running tests under Python 3.7.13: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2022-05-19 16:01:04.854840: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# W0519 16:01:05.082639 140454571095936 model_builder.py:1102] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.48s
# I0519 16:01:05.445601 140454571095936 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.48s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.52s
# ...

# %% [markdown]
# ## Imports and Config

# %%
import tensorflow as tf

from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
tf.__version__
# Out:
# '2.7.0'

# %%
#PRETRAINED_MODEL_PATH="/content/drive/MyDrive/helmet_detection/data/tensorflow/models/pre_trained_model"

# %%
#!mkdir /content/drive/MyDrive/helmet_detection/data/tensorflow/models/pre_trained_model

# %%
#!wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz

# %%
cd /content/drive/MyDrive/helmet_detection/data/tensorflow/models/pre_trained_model
# Out:
# /content/drive/.shortcut-targets-by-id/1pKyLFjpE3px_b4yXeAi4oKdIQqIqvHIp/helmet_detection/data/tensorflow/models/pre_trained_model

# %%
#!tar -xvf ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz

# %%
config_path="/content/drive/MyDrive/helmet_detection/data/tensorflow/models/pre_trained_model/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/pipeline.config"
config = config_util.get_configs_from_pipeline_file(config_path)
config
# Out:
# {'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_config': label_map_path: "/content/drive/MyDrive/helmet_detection/data/label_map.pbtxt"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "/content/drive/MyDrive/helmet_detection/data/train.record"
#  },
#  'eval_input_configs': [label_map_path: "/content/drive/MyDrive/helmet_detection/data/label_map.pbtxt"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "/content/drive/MyDrive/helmet_detection/data/train.record"
#  }
#  ],
#  'model': ssd {
#    num_classes: 2
#    image_resizer {
#      fixed_shape_resizer {
#        height: 640
#        width: 640
#      }
#    }
#    feature_extractor {
#      type: "ssd_resnet101_v1_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 0.00039999998989515007
#          }
#        }
# ...

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(config_path, "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
   tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# # Train

# %%
# !python3 /content/drive/MyDrive/helmet_detection/data/tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=/content/drive/MyDrive/helmet_detection/data/tensorflow/models/pre_trained_model/helmet_detection --pipeline_config_path=/content/drive/MyDrive/helmet_detection/data/tensorflow/models/pre_trained_model/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/pipeline.config
# Out:
# 2022-05-19 16:03:16.621827: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0519 16:03:16.626976 139978587649920 mirrored_strategy.py:376] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0519 16:03:16.634176 139978587649920 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0519 16:03:16.634358 139978587649920 config_util.py:552] Maybe overwriting use_bfloat16: False
# ...

# %%
# cd /content/drive/MyDrive/helmet_detection/data/tensorflow/models/research
# Out:
# /content/drive/.shortcut-targets-by-id/1pKyLFjpE3px_b4yXeAi4oKdIQqIqvHIp/helmet_detection/data/tensorflow/models/research

# %%
# !conda --version
# Out:
# /bin/bash: conda: command not found

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:36
# 🔁 Restarting kernel...
